# %% [markdown]
# <a href="https://colab.research.google.com/github/merriekay/ASL_translate/blob/main/Lab01_CS65_F22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Hello World
#
# Work through the following exercises and reflection questions. For credit on the lab, you only have to submit a very simple "Hello world!" program at the end of the lab, but the rest will help you in future labs and quizzes.
#
# For each of the reflection questions, discuss with your group and write answers in your notes.
#
# ## Exercise 1:
# Run this line of code (as a script or in the interactive shell):

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# ## Exercise 2
# What happens when you run each of the following lines?

# %%
print("Isn't it a nice day out?")
print('Isn't it a nice day out?')

# %% [markdown]
# - Why did the second one give you an eror?
# - Why do you think Python allows you to use both `"` and `'`?
# - How can you get a `"` symbol to print?
# - How can you get a `'` symbol to print?

# %% [markdown]
# ## Exercise 3:
# The following print statement contains a special symbol, `\n`, that does something strange.

# %%
print("here is some text\nhere is more text")

# %% [markdown]
# `\n` is called the *newline* character. Why do you think it is called that?
#
# ## Exercise 4:
# There are other special characters too. Experiment with these: `\t`, `\\`
# - what do each of these do?
# - Why do you think it is necessary fo rPyhon to support specia text characters like these?

# %% [markdown]
# ## Challenge Exercise
# For the points on this lab, wirte a Python program which displays the message "Hello World!". Save it as `HelloWorld.py`. When you run it in Thonny, it should look like this:
#
# ![L1_goal.png](data:image/png;base64,...)

# %% [markdown]
# When you are finished, upload your `HelloWorld.py` file to the codePost **Hello World** assignment.
